# %%
import pandas as pd
import seaborn as sns
data = sns.load_dataset("titanic")

# %%
# How to write a file
data.to_excel("../Datasets/titanic_data.xlsx")

# %%
# How to read a file
import pandas as pd
df = pd.read_excel("../Datasets/titanic_data.xlsx")

# %%
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# Pandas 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
# top rows
df.head(10)
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
# 5           5         0       3    male   NaN      0      0   8.4583        Q
# 6           6         0       1    male  54.0      0      0  51.8625        S
# 7           7         0       3    male   2.0      3      1  21.0750        S
# 8           8         1       3  female  27.0      0      2  11.1333        S
# 9           9         1       2  female  14.0      1      0  30.0708        C
#
#     class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch   fare embarked  \
# 886         886         0       2    male  27.0      0      0  13.00        S
# 887         887         1       1  female  19.0      0      0  30.00        S
# 888         888         0       3  female   NaN      1      2  23.45        S
# 889         889         1       1    male  26.0      0      0  30.00        C
# 890         890         0       3    male  32.0      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True

# %% [markdown]
# # **Basic Data Structures in Pandas**

# %% [markdown]
# Panadas Provides two types of classes for handling data.
# 1. **Series:** A one-dimensional labeled array capable of holding any data type (integer, string, float, python objects etc)
# 2. **DataFrame:** A two-dimensional table of values with column labels with row labels.

# %% [markdown]
# ## **1. Object Creation**

# %%
# Object Creation
a = pd.Series([1,2,3,6,8])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# 4    8
# dtype: int64

# %%
# creatinga a Data frame using pandas
dates = pd.date_range("20130101", periods = 6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# creating a data frame a by passing a dictionary of objects
import numpy as np
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# ## **2. Viewing data**

# %%
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
df.tail(3)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch   fare embarked  \
# 888         888         0       3  female   NaN      1      2  23.45        S
# 889         889         1       1    male  26.0      0      0  30.00        C
# 890         890         0       3    male  32.0      0      0   7.75        Q
#
#      class    who  adult_male deck  embark_town alive  alone
# 888  Third  woman       False  NaN  Southampton    no  False
# 889  First    man        True    C    Cherbourg   yes   True
# 890  Third    man        True  NaN   Queenstown    no   True

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.to_numpy()
# Out:
# array([[0, 0, 3, ..., 'Southampton', 'no', False],
#        [1, 1, 1, ..., 'Cherbourg', 'yes', False],
#        [2, 1, 3, ..., 'Southampton', 'yes', True],
#        ...,
#        [888, 0, 3, ..., 'Southampton', 'no', False],
#        [889, 1, 1, ..., 'Cherbourg', 'yes', True],
#        [890, 0, 3, ..., 'Queenstown', 'no', True]],
#       shape=(891, 16), dtype=object)

# %%
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
# Transporing your data
df.T
# Out:
#                      0          1            2            3            4    \
# Unnamed: 0             0          1            2            3            4
# survived               0          1            1            1            0
# pclass                 3          1            3            1            3
# sex                 male     female       female       female         male
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# parch                  0          0            0            0            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# ...

# %%
# sort by an axis
df.sort_index(axis=1, ascending=False)
# Out:
#        who  survived  sibsp     sex  pclass  parch     fare embarked  \
# 0      man         0      1    male       3      0   7.2500        S
# 1    woman         1      1  female       1      0  71.2833        C
# 2    woman         1      0  female       3      0   7.9250        S
# 3    woman         1      1  female       1      0  53.1000        S
# 4      man         0      0    male       3      0   8.0500        S
# ..     ...       ...    ...     ...     ...    ...      ...      ...
# 886    man         0      0    male       2      0  13.0000        S
# 887  woman         1      0  female       1      0  30.0000        S
# 888  woman         0      1  female       3      2  23.4500        S
# 889    man         1      0    male       1      0  30.0000        C
# 890    man         0      0    male       3      0   7.7500        Q
#
#      embark_town deck   class  alone alive   age  adult_male  Unnamed: 0
# ...

# %%
# sort by values
df.sort_values(by="fare")
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch      fare  \
# 815         815         0       1    male   NaN      0      0    0.0000
# 806         806         0       1    male  39.0      0      0    0.0000
# 413         413         0       2    male   NaN      0      0    0.0000
# 481         481         0       2    male   NaN      0      0    0.0000
# 302         302         0       3    male  19.0      0      0    0.0000
# ..          ...       ...     ...     ...   ...    ...    ...       ...
# 438         438         0       1    male  64.0      1      4  263.0000
# 341         341         1       1  female  24.0      3      2  263.0000
# 737         737         1       1    male  35.0      0      0  512.3292
# 679         679         1       1    male  36.0      0      1  512.3292
# 258         258         1       1  female  35.0      0      0  512.3292
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## **3. Selection**

# %%
df["fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
df[1:6]
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
# 5           5         0       3    male   NaN      0      0   8.4583        Q
#
#    class    who  adult_male deck  embark_town alive  alone
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True
# 5  Third    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ## **4. Selection by Labels**

# %%
# selecting a row matching a label
df.loc[df['fare'] == '0']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
# selecting all rows with a select columns labels
df_3 = df.loc[:, ['age', 'sibsp', 'fare']]

# %%
df_3
# Out:
#       age  sibsp     fare
# 0    22.0      1   7.2500
# 1    38.0      1  71.2833
# 2    26.0      0   7.9250
# 3    35.0      1  53.1000
# 4    35.0      0   8.0500
# ..    ...    ...      ...
# 886  27.0      0  13.0000
# 887  19.0      0  30.0000
# 888   NaN      1  23.4500
# 889  26.0      0  30.0000
# 890  32.0      0   7.7500
#
# [891 rows x 3 columns]

# %%
df.loc["0": "70", ["age", "fare"]]
# Out:
#       age      fare
# 0    22.0    7.2500
# 1    38.0   71.2833
# 2    26.0    7.9250
# 3    35.0   53.1000
# 4    35.0    8.0500
# ..    ...       ...
# 695  52.0   13.5000
# 696  44.0    8.0500
# 697   NaN    7.7333
# 698  49.0  110.8833
# 699  42.0    7.6500
#
# [700 rows x 2 columns]

# %% [markdown]
# ## **4. Selecting by Position**

# %%
df.iloc[3]
# Out:
# Unnamed: 0               3
# survived                 1
# pclass                   1
# sex                 female
# age                   35.0
# sibsp                    1
# parch                    0
# fare                  53.1
# embarked                 S
# class                First
# who                  woman
# adult_male           False
# deck                     C
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 3, dtype: object

# %%
df.iloc[3:5, 0:2]
# Out:
#    Unnamed: 0  survived
# 3           3         1
# 4           4         0

# %% [markdown]
# ## **5. Boolean Indexing**

# %%
# select rows where boolean condition satisfied
df_filtered = df[df['age'] > 50]
df_filtered
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 6             6         0       1    male  54.0      0      0  51.8625
# 11           11         1       1  female  58.0      0      0  26.5500
# 15           15         1       2  female  55.0      0      0  16.0000
# 33           33         0       2    male  66.0      0      0  10.5000
# 54           54         0       1    male  65.0      0      1  61.9792
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 820         820         1       1  female  52.0      1      1  93.5000
# 829         829         1       1  female  62.0      0      0  80.0000
# 851         851         0       3    male  74.0      0      0   7.7750
# 857         857         1       1    male  51.0      0      0  26.5500
# 879         879         1       1  female  56.0      0      1  83.1583
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## **6. Setting**

# %%
# Setting a new column automatically aligns the data by the indexes:
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df2["F"] = s1

# %%
df2
# Out:
#      A          B    C  D      E   F
# 0  1.0 2013-01-02  1.0  3   test NaN
# 1  1.0 2013-01-02  1.0  3  train NaN
# 2  1.0 2013-01-02  1.0  3   test NaN
# 3  1.0 2013-01-02  1.0  3  train NaN

# %% [markdown]
# ## **7. Missing Data**

# %%
# how to drop rows
# df.dropna()  # drop rows with missing values
df.dropna(how= 'any')
# fills missing values
df.fillna(0)  # fills missing values with 0
df.fillna(value=5)
# isna() gets the boolean mask where values are nan:
pd.isna(df)

# %% [markdown]
# ## **8. Operations**

# %%
# stats
# caluclate mean value for each column
df.mean()
# mean value for each row
df.mean(axis=1)
# median
df.median()
# mode
df.mode()
# standard deviation
df.std()
# variance
df.var()
